# %%
import pandas as pd

# %%
swedish = pd.read_csv("data/swedish_dataset.csv")

# %%
tcga = pd.read_csv("data/TCGA817-FULL_SET.csv")

# %%
gene_set = np.random.choice(common_indices, 50, replace=False).tolist()

# %%
swedish = swedish.drop(["expert_PAM50_subtypes"], axis=1)

# %%
swedish_2 = swedish.apply(lambda x: 2**x-0.1).apply(lambda x: np.log2(x+1))

# %%
sw_mean = swedish_2.mean().mean()

# %%
tcga_mean = tcga.mean().mean()

# %%
tcga_median = tcga.mean().median()

# %%
sw_mean
# Out:
# 1.642275851419889

# %%
swedish_median = swedish_2.mean().median()

# %%
tcga_mean
# Out:
# 6.716853056518055

# %%
swedish_2.mean().hist(bins=100, figsize=(30, 10))
plt.xlim(0,18)
# Out:
# (0, 18)

# %%
tcga.mean().hist(bins=100, figsize=(30, 10))
plt.xlim(0,18)
# Out:
# (0, 18)

# %%
swedish_3 = swedish_2.apply(lambda x: x/sw_mean)

# %%
tcga = tcga.drop("Ciriello_subtype", axis=1)

# %%
tcga = tcga.drop("TCGA_ID", axis=1)

# %%
tcga_3 = tcga.apply(lambda x: x/tcga_mean)

# %%
import matplotlib.pyplot as plt
box_swedish = swedish_3.boxplot(column=gene_set, figsize=(30, 5))
plt.ylim(0,7)

box_swedish.plot
# Out:
# <bound method Axes.plot of <matplotlib.axes._subplots.AxesSubplot object at 0x7f525991c5c0>>

# %%
box_tcga = tcga_3.boxplot(column=gene_set, figsize=(30,5))
plt.ylim(0,7)
box_tcga.plot
# Out:
# <bound method Axes.plot of <matplotlib.axes._subplots.AxesSubplot object at 0x7f5261130c18>>

# %%
swedish_indices = swedish.columns

# %%
brca_indices = tcga.columns

# %%
common_indices = list(set(brca_indices).intersection(swedish_indices))

# %%
common_indices[:15]
# Out:
# ['STAC2',
#  'HDAC9',
#  'AXIN2',
#  'CRYBB3',
#  'OR4A47',
#  'TMLHE',
#  'DGKB',
#  'GRASP',
#  'ART5',
#  'GSTZ1',
#  'IRAK3',
#  'LRRC37A',
#  'ZNF334',
#  'PLEKHA8P1',
#  'LCE6A']

# %%
len(common_indices)
# Out:
# 18611

# %%
import random

# %%
import numpy as np

# %%
gene_set = np.random.choice(common_indices, 20, replace=False)

# %%
gene_set
# Out:
# array(['TXNDC2', 'ARHGEF1', 'FANCL', 'LPAR3', 'BEND6', 'ARHGEF28',
#        'DCBLD2', 'PIK3CD', 'MDM2', 'DDX10', 'MYCL', 'IGFBP5', 'OR2B11',
#        'HEG1', 'LLGL1', 'PRKRIR', 'SLC25A45', 'CNTF', 'ATOH7', 'TJP1'],
#       dtype='<U13')

# %%
from sklearn.preprocessing import StandardScaler

# %%
mean_swedish=swedish.mean(axis=1, numeric_only=True)

# %%
final_mean = mean_swedish.sum()/len(mean_swedish)

# %%
final_mean
# Out:
# -0.01631159488532939

# %%
swedish_3 = swedish[['TXNDC2', 'ARHGEF1', 'FANCL', 'LPAR3', 'BEND6', 'ARHGEF28', 'DCBLD2', 'PIK3CD', 'MDM2', 'DDX10', 'MYCL', 'IGFBP5', 'OR2B11', 'HEG1', 'LLGL1', 'PRKRIR', 'SLC25A45', 'CNTF', 'ATOH7', 'TJP1']].apply(lambda x: np.log(x)+1)
# Out:
# /home/cristovao/miniconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in log
#   """Entry point for launching an IPython kernel.

# %%
import pandas as pd
data_tcga = pd.read_csv("/home/nanni/Data/TCGA/Xena/tcga.tsv", sep="\t")
# Out:
# /home/cristovao/miniconda3/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3044: DtypeWarning: Columns (3,4) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_tcga
# Out:
#                 sample tumor_type project tissue_site participant  \
# 0      TCGA-L5-A4OF-01       ESCA    TCGA          L5        A4OF
# 1      TCGA-LN-A49R-01       ESCA    TCGA          LN        A49R
# 2      TCGA-Z6-A9VB-01       ESCA    TCGA          Z6        A9VB
# 3      TCGA-L5-A8NF-01       ESCA    TCGA          L5        A8NF
# 4      TCGA-2H-A9GG-01       ESCA    TCGA          2H        A9GG
# 5      TCGA-IG-A3QL-01       ESCA    TCGA          IG        A3QL
# 6      TCGA-VR-AA7B-01       ESCA    TCGA          VR        AA7B
# 7      TCGA-2H-A9GN-01       ESCA    TCGA          2H        A9GN
# 8      TCGA-L7-A6VZ-01       ESCA    TCGA          L7        A6VZ
# 9      TCGA-L5-A4OF-11       ESCA    TCGA          L5        A4OF
# 10     TCGA-IG-A4QS-01       ESCA    TCGA          IG        A4QS
# 11     TCGA-LN-A5U6-01       ESCA    TCGA          LN        A5U6
# 12     TCGA-LN-A9FP-01       ESCA    TCGA          LN        A9FP
# ...

# %%
data_tcga.to_csv("data/TCGA_source/tcga_all", index=False)

# %%
tcga_brca = data_tcga[data_tcga["tumor_type"]=="BRCA"]

# %%
tcga_brca.to_csv("data/TCGA_source/tcga_all_brca",index=False)
